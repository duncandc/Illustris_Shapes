# %%
import numpy as np
import matplotlib.pyplot as plt
from __future__ import print_function, division
# %matplotlib inline

# %% [markdown]
# # Shape Correlations

# %%
from astropy.table import Table
fname = simname + '_' + str(snapNum) + '_' + 'reduced' + '_' +'galaxy_shapes'+ '.dat' 
t_1 = Table.read('../data/shape_catalogs/'+fname, format='ascii')

from Illustris_Shapes.simulation_props import sim_prop_dict
d = sim_prop_dict[simname]
basePath = d['basePath']
Lbox = d['Lbox']
from illustris_python.groupcat import gcPath, loadHalos, loadSubhalos
coords = loadSubhalos(basePath, snapNum, fields=['SubhaloPos'])/1000.0
coord = coords[t_1['gal_id']]

# %%
from halotools.mock_observables.alignments import ed_3d, ee_3d

# %%
# Out:
# <Table length=27345>
# gal_id         a          ...         cv_y                  cv_z
# int64       float64       ...       float64               float64
# ------ ------------------ ... -------------------- ---------------------
#      0 0.6787176165511027 ...    0.636850163231966   -0.2844892794623783
#      1  0.628388652005401 ...  0.29819455704400816    0.8916280094347775
#      2 0.6561983835971344 ... 0.048428488508559124    0.8035123822207129
#      3 0.6609946466539327 ...   0.6874157927951432    0.5007311550973904
#      4 0.6692501042705059 ...  -0.7143109953823822   0.07801436714724772
#      5 0.6316499642821821 ...   0.7878216690981018   -0.6138982783384193
#      6 0.6500423429136127 ...  0.24334601618420293 -0.014859515014712258
#      7 0.7036832240202472 ...   0.5613088126509928   -0.7440884120908208
#      8 0.6942278889352056 ...  0.25786811381534686   0.22788397443664704
#      9 0.6591372184063167 ... -0.31187936688657864    0.2660403486233222
#    ...                ... ...                  ...                   ...
# 702443 0.5925548198256356 ...    0.915200085123947   0.33176393235778784
# 709081 0.5968751038624526 ...   0.8087830203477857   0.09429158723504494
# 717297 0.5968621536945491 ... -0.14710029252052734   -0.8605674482105166
# 717843 0.6182965717032008 ...   0.6124366122711463   -0.3599621659815214
# 721242 0.6000370347872738 ...  -0.5479924566302247   -0.7428974258201445
# 721529 0.5875429547092289 ...   -0.565485221914607   -0.4746398718960404
# 725443 0.5887439651098483 ...   0.7339596203294178   -0.1283707192987876
# 726717 0.5973905777537888 ...    0.926001912008513   0.22921798559864723
# 729829 0.5857781048198757 ...   0.3776909740641957     0.923592836464122
# 739605 0.6043362582860503 ...   0.8496868052431347   0.13629818531075796
